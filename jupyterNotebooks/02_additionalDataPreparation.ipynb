# %%
import pandas as pd
import numpy as np
import math

# %%
#read weather data. its timestamp is already in date/hour format
weather = pd.read_csv('../data/raw/hourlyWeatherSummary_2015_2016.csv')
weather['date_hour'] = weather['timestamp'].apply(pd.Timestamp)
weather = weather.drop('timestamp', axis=1)

#add time features
weather['date'] = weather['date_hour'].dt.date
weather['hour'] = weather['date_hour'].dt.hour
weather['weekday'] = weather['date_hour'].dt.weekday
weather['month'] = weather['date_hour'].dt.month
weather['year'] = weather['date_hour'].dt.year
weather.head()
# Out:
#    apparentTemperature  cloudCover  dewPoint  humidity                 icon  \
# 0               -10.83        0.22    -11.59      0.63          clear-night
# 1               -11.83        0.17    -12.09      0.62          clear-night
# 2               -12.07        0.06    -12.44      0.60          clear-night
# 3               -11.53        0.07    -12.67      0.57          clear-night
# 4               -11.01        0.34    -12.96      0.53  partly-cloudy-night
#
#    precipAccumulation  precipIntensity  precipProbability precipType  \
# 0                 NaN              0.0                0.0        NaN
# 1                 NaN              0.0                0.0        NaN
# 2                 NaN              0.0                0.0        NaN
# 3                 NaN              0.0                0.0        NaN
# 4                 NaN              0.0                0.0        NaN
#
#    pressure  ...  uvIndex  visibility  windBearing  windSpeed  \
# 0   1019.96  ...      0.0       15.40          229       3.42
# 1   1019.03  ...      0.0       15.26          226       4.31
# 2   1018.15  ...      0.0       15.48          232       4.47
# 3   1017.48  ...      0.0       15.42          236       4.74
# 4   1016.75  ...      0.0       15.51          242       5.17
#
#                   date_hour        date hour weekday  month  year
# 0 2015-01-01 00:00:00-05:00  2015-01-01    0       3      1  2015
# 1 2015-01-01 01:00:00-05:00  2015-01-01    1       3      1  2015
# 2 2015-01-01 02:00:00-05:00  2015-01-01    2       3      1  2015
# 3 2015-01-01 03:00:00-05:00  2015-01-01    3       3      1  2015
# 4 2015-01-01 04:00:00-05:00  2015-01-01    4       3      1  2015
#
# [5 rows x 22 columns]

# %%
#read holiday data
holidays = pd.read_csv('../data/raw/publicHolidays_2015_2016.csv')
holidays['date'] = holidays['date'].apply(pd.Timestamp).dt.date
holidays.head()
# Out:
#                    description        date
# 0               New Year's Day  2015-01-01
# 1  Martin Luther King, Jr. Day  2015-01-19
# 2              Presidents' Day  2015-02-16
# 3               Evacuation Day  2015-03-17
# 4                Patriots' Day  2015-04-20

# %%
#merge weather and holidays.
additional_features = weather.merge(holidays, how='left', on=('date'))

#add features to mark holidays and weekends
additional_features = additional_features.rename(columns={'description': 'holiday_description'})
additional_features['is_holiday'] = 1 * additional_features['holiday_description'].notnull()
additional_features['is_weekend'] = 1 * ((additional_features['weekday'] == 5) | (additional_features['weekday'] == 6))
additional_features['is_weekend_or_holiday'] = 1 * (additional_features['is_weekend'] | additional_features['is_holiday'])
additional_features = additional_features.set_index('date_hour')
additional_features.head()
# Out:
#                            apparentTemperature  cloudCover  dewPoint  \
# date_hour
# 2015-01-01 00:00:00-05:00               -10.83        0.22    -11.59
# 2015-01-01 01:00:00-05:00               -11.83        0.17    -12.09
# 2015-01-01 02:00:00-05:00               -12.07        0.06    -12.44
# 2015-01-01 03:00:00-05:00               -11.53        0.07    -12.67
# 2015-01-01 04:00:00-05:00               -11.01        0.34    -12.96
#
#                            humidity                 icon  precipAccumulation  \
# date_hour
# 2015-01-01 00:00:00-05:00      0.63          clear-night                 NaN
# 2015-01-01 01:00:00-05:00      0.62          clear-night                 NaN
# 2015-01-01 02:00:00-05:00      0.60          clear-night                 NaN
# 2015-01-01 03:00:00-05:00      0.57          clear-night                 NaN
# 2015-01-01 04:00:00-05:00      0.53  partly-cloudy-night                 NaN
#
#                            precipIntensity  precipProbability precipType  \
# date_hour
# 2015-01-01 00:00:00-05:00              0.0                0.0        NaN
# 2015-01-01 01:00:00-05:00              0.0                0.0        NaN
# 2015-01-01 02:00:00-05:00              0.0                0.0        NaN
# 2015-01-01 03:00:00-05:00              0.0                0.0        NaN
# 2015-01-01 04:00:00-05:00              0.0                0.0        NaN
#
#                            pressure          ...           windSpeed  \
# date_hour                                    ...
# 2015-01-01 00:00:00-05:00   1019.96          ...                3.42
# 2015-01-01 01:00:00-05:00   1019.03          ...                4.31
# 2015-01-01 02:00:00-05:00   1018.15          ...                4.47
# 2015-01-01 03:00:00-05:00   1017.48          ...                4.74
# 2015-01-01 04:00:00-05:00   1016.75          ...                5.17
#
#                                  date  hour  weekday  month  year  \
# date_hour
# 2015-01-01 00:00:00-05:00  2015-01-01     0        3      1  2015
# 2015-01-01 01:00:00-05:00  2015-01-01     1        3      1  2015
# 2015-01-01 02:00:00-05:00  2015-01-01     2        3      1  2015
# 2015-01-01 03:00:00-05:00  2015-01-01     3        3      1  2015
# 2015-01-01 04:00:00-05:00  2015-01-01     4        3      1  2015
#
#                           holiday_description  is_holiday  is_weekend  \
# date_hour
# 2015-01-01 00:00:00-05:00      New Year's Day           1           0
# 2015-01-01 01:00:00-05:00      New Year's Day           1           0
# 2015-01-01 02:00:00-05:00      New Year's Day           1           0
# 2015-01-01 03:00:00-05:00      New Year's Day           1           0
# 2015-01-01 04:00:00-05:00      New Year's Day           1           0
#
#                            is_weekend_or_holiday
# date_hour
# 2015-01-01 00:00:00-05:00                      1
# 2015-01-01 01:00:00-05:00                      1
# 2015-01-01 02:00:00-05:00                      1
# 2015-01-01 03:00:00-05:00                      1
# 2015-01-01 04:00:00-05:00                      1
#
# [5 rows x 25 columns]

# %%
additional_features.to_csv('../data/modelInput/additionalFeatures.csv')
